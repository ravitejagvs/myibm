# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods in Toronto</font></h1>

# %% [markdown]
# *importing modules*

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from requests import get
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response = get(url)

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## Webscraping to create a pandas dataset

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
html_content = requests.get(url).text
soup = BeautifulSoup(html_content, "html.parser")

# %%
postalCode = []
borough = []
neighborhood = []

# append the data into the respective lists
for row in soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        postalCode.append(cells[0].text.rstrip('\n'))
        borough.append(cells[1].text.rstrip('\n'))
        neighborhood.append(cells[2].text.rstrip('\n'))

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %%
toronto_df = pd.DataFrame({"PostalCode": postalCode,
                           "Borough": borough,
                           "Neighborhood": neighborhood})

# %%
toronto_df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# # Cleaning the dataset

# %% [markdown]
# Make sure that the dataset has all  boroughs and neighborhoods without NA

# %%
toronto_df_na = toronto_df[toronto_df.Borough != "Not assigned"].reset_index(drop=True)
toronto_df_na.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
for index, row in toronto_df_na.iterrows():
    if row["Neighborhood"] == "Not assigned":
        row["Neighborhood"] = row["Borough"]
        
toronto_df_na.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
toronto_df_group = toronto_df_na.groupby(["PostalCode", "Borough"], as_index=False).agg(lambda x: ", ".join(x))
toronto_df_group.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
toronto_df_group.shape
# Out:
# (103, 3)

# %%
coordinates = pd.read_csv("/content/Geospatial_Coordinates.csv")

# %%
coordinates.rename(columns={"Postal Code": "PostalCode"}, inplace=True)

# %%
toronto_df_new = toronto_df_group.merge(coordinates, on="PostalCode", how="left")
toronto_df_new.head()
# Out:
#   PostalCode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %% [markdown]
# # Visualising the dataset using Foursquare

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[toronto_df_new['Latitude'][0], toronto_df_new['Longitude'][0]], zoom_start=10)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define Foursquare Credentials and Version
CLIENT_ID = 'CWO1LL1IQ2E1X303BQXMEE5JXBMLQXVZD1EPXC444EOQZJRP' # your Foursquare ID
CLIENT_SECRET = 'IMI3DHELIM1PGU35FB10WNPAT1QWVBW5AGXUAFQBVP5X4OY5' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['Borough'], toronto_df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# filter borough names that contain the word Toronto
borough_names = list(toronto_df_new.Borough.unique())

borough_with_toronto = []

for x in borough_names:
    if "toronto" in x.lower():
        borough_with_toronto.append(x)
        
borough_with_toronto
# Out:
# ['East Toronto', 'Central Toronto', 'Downtown Toronto', 'West Toronto']

# %%
toronto_df_new = toronto_df_new[toronto_df_new['Borough'].isin(borough_with_toronto)].reset_index(drop=True)
print(toronto_df_new.shape)
toronto_df_new.head()
# Out:
# (39, 5)
#   PostalCode          Borough  ...   Latitude  Longitude
# 0        M4E     East Toronto  ...  43.676357 -79.293031
# 1        M4K     East Toronto  ...  43.679557 -79.352188
# 2        M4L     East Toronto  ...  43.668999 -79.315572
# 3        M4M     East Toronto  ...  43.659526 -79.340923
# 4        M4N  Central Toronto  ...  43.728020 -79.388790
#
# [5 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim
address = 'Toronto'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['Borough'], toronto_df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Exploring neighborhoods

# %%
from pandas.io.json import json_normalize
import json
radius = 500
LIMIT = 100

venues = []

for lat, long, post, borough, neighborhood in zip(toronto_df_new['Latitude'], toronto_df_new['Longitude'], toronto_df_new['PostalCode'], toronto_df_new['Borough'], toronto_df_new['Neighborhood']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            post, 
            borough,
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
# convert the venues list into a new DataFrame
venues_df = pd.DataFrame(venues)

# define the column names
venues_df.columns = ['PostalCode', 'Borough', 'Neighborhood', 'BoroughLatitude', 'BoroughLongitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(venues_df.shape)
venues_df.head()
# Out:
# (1618, 9)
#   PostalCode       Borough  ... VenueLongitude      VenueCategory
# 0        M4E  East Toronto  ...     -79.293942              Trail
# 1        M4E  East Toronto  ...     -79.297734  Health Food Store
# 2        M4E  East Toronto  ...     -79.297215                Pub
# 3        M4E  East Toronto  ...     -79.292869       Neighborhood
# 4        M4K  East Toronto  ...     -79.351265     Cosmetics Shop
#
# [5 rows x 9 columns]

# %%
venues_df_gp = venues_df.groupby(["PostalCode", "Borough", "Neighborhood"])
venues_df_gp.head()
# Out:
#      PostalCode       Borough  ... VenueLongitude      VenueCategory
# 0           M4E  East Toronto  ...     -79.293942              Trail
# 1           M4E  East Toronto  ...     -79.297734  Health Food Store
# 2           M4E  East Toronto  ...     -79.297215                Pub
# 3           M4E  East Toronto  ...     -79.292869       Neighborhood
# 4           M4K  East Toronto  ...     -79.351265     Cosmetics Shop
# ...         ...           ...  ...            ...                ...
# 1602        M7Y  East Toronto  ...     -79.319824            Brewery
# 1603        M7Y  East Toronto  ...     -79.319784     Farmers Market
# 1604        M7Y  East Toronto  ...     -79.325162         Comic Shop
# 1605        M7Y  East Toronto  ...     -79.325584      Burrito Place
# 1606        M7Y  East Toronto  ...     -79.324164        Pizza Place
#
# [185 rows x 9 columns]

# %%
print('There are {} uniques categories.'.format(len(venues_df['VenueCategory'].unique())))
# Out:
# There are 237 uniques categories.

# %% [markdown]
# ## Analyse each area

# %%
# one hot encoding for categorical nominal data
toronto_onehot = pd.get_dummies(venues_df[['VenueCategory']], prefix="", prefix_sep="")

# add postal, borough and neighborhood column back to dataframe
toronto_onehot['PostalCode'] = venues_df['PostalCode'] 
toronto_onehot['Borough'] = venues_df['Borough'] 
toronto_onehot['Neighborhoods'] = venues_df['Neighborhood'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(toronto_onehot.columns[-3:]) + list(toronto_onehot.columns[:-3])
toronto_onehot = toronto_onehot[fixed_columns]

print(toronto_onehot.shape)
toronto_onehot.head()
# Out:
# (1618, 240)
#   PostalCode       Borough  ... Women's Store  Yoga Studio
# 0        M4E  East Toronto  ...             0            0
# 1        M4E  East Toronto  ...             0            0
# 2        M4E  East Toronto  ...             0            0
# 3        M4E  East Toronto  ...             0            0
# 4        M4K  East Toronto  ...             0            0
#
# [5 rows x 240 columns]

# %%
toronto_grouped = toronto_onehot.groupby(["PostalCode", "Borough", "Neighborhoods"]).mean().reset_index()

print(toronto_grouped.shape)
toronto_grouped
# Out:
# (39, 240)
#    PostalCode           Borough  ... Women's Store  Yoga Studio
# 0         M4E      East Toronto  ...      0.000000     0.000000
# 1         M4K      East Toronto  ...      0.000000     0.023256
# 2         M4L      East Toronto  ...      0.000000     0.000000
# 3         M4M      East Toronto  ...      0.000000     0.024390
# 4         M4N   Central Toronto  ...      0.000000     0.000000
# 5         M4P   Central Toronto  ...      0.000000     0.000000
# 6         M4R   Central Toronto  ...      0.000000     0.052632
# 7         M4S   Central Toronto  ...      0.000000     0.000000
# 8         M4T   Central Toronto  ...      0.000000     0.000000
# 9         M4V   Central Toronto  ...      0.000000     0.000000
# 10        M4W  Downtown Toronto  ...      0.000000     0.000000
# 11        M4X  Downtown Toronto  ...      0.000000     0.000000
# 12        M4Y  Downtown Toronto  ...      0.000000     0.025641
# 13        M5A  Downtown Toronto  ...      0.000000     0.021739
# 14        M5B  Downtown Toronto  ...      0.000000     0.000000
# 15        M5C  Downtown Toronto  ...      0.000000     0.000000
# 16        M5E  Downtown Toronto  ...      0.000000     0.000000
# 17        M5G  Downtown Toronto  ...      0.000000     0.015385
# 18        M5H  Downtown Toronto  ...      0.010526     0.000000
# 19        M5J  Downtown Toronto  ...      0.000000     0.000000
# 20        M5K  Downtown Toronto  ...      0.000000     0.000000
# 21        M5L  Downtown Toronto  ...      0.000000     0.000000
# 22        M5N   Central Toronto  ...      0.000000     0.000000
# 23        M5P   Central Toronto  ...      0.000000     0.000000
# 24        M5R   Central Toronto  ...      0.000000     0.000000
# 25        M5S  Downtown Toronto  ...      0.000000     0.028571
# 26        M5T  Downtown Toronto  ...      0.000000     0.000000
# 27        M5V  Downtown Toronto  ...      0.000000     0.000000
# 28        M5W  Downtown Toronto  ...      0.000000     0.010638
# 29        M5X  Downtown Toronto  ...      0.000000     0.000000
# 30        M6G  Downtown Toronto  ...      0.000000     0.000000
# 31        M6H      West Toronto  ...      0.000000     0.000000
# 32        M6J      West Toronto  ...      0.000000     0.022222
# 33        M6K      West Toronto  ...      0.000000     0.000000
# 34        M6P      West Toronto  ...      0.000000     0.000000
# 35        M6R      West Toronto  ...      0.000000     0.000000
# 36        M6S      West Toronto  ...      0.000000     0.026316
# 37        M7A  Downtown Toronto  ...      0.000000     0.031250
# 38        M7Y      East Toronto  ...      0.000000     0.062500
#
# [39 rows x 240 columns]

# %% [markdown]
# Display top venues. I chose 8 venues

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
areaColumns = ['PostalCode', 'Borough', 'Neighborhoods']
freqColumns = []
for ind in np.arange(num_top_venues):
    try:
        freqColumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        freqColumns.append('{}th Most Common Venue'.format(ind+1))
columns = areaColumns+freqColumns

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['PostalCode'] = toronto_grouped['PostalCode']
neighborhoods_venues_sorted['Borough'] = toronto_grouped['Borough']
neighborhoods_venues_sorted['Neighborhoods'] = toronto_grouped['Neighborhoods']

for ind in np.arange(toronto_grouped.shape[0]):
    row_categories = toronto_grouped.iloc[ind, :].iloc[3:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    neighborhoods_venues_sorted.iloc[ind, 3:] = row_categories_sorted.index.values[0:num_top_venues]

# neighborhoods_venues_sorted.sort_values(freqColumns, inplace=True)
print(neighborhoods_venues_sorted.shape)
neighborhoods_venues_sorted
# Out:
# (39, 13)
#    PostalCode  ...       10th Most Common Venue
# 0         M4E  ...             Doner Restaurant
# 1         M4K  ...          Japanese Restaurant
# 2         M4L  ...                   Restaurant
# 3         M4M  ...                         Park
# 4         M4N  ...                   Donut Shop
# 5         M4P  ...               Discount Store
# 6         M4R  ...           Miscellaneous Shop
# 7         M4S  ...                     Pharmacy
# 8         M4T  ...                   Donut Shop
# 9         M4V  ...                  Supermarket
# 10        M4W  ...                   Donut Shop
# 11        M4X  ...                        Diner
# 12        M4Y  ...                        Hotel
# 13        M5A  ...               Farmers Market
# 14        M5B  ...         Fast Food Restaurant
# 15        M5C  ...               Lingerie Store
# 16        M5E  ...                    Irish Pub
# 17        M5G  ...   Modern European Restaurant
# 18        M5H  ...                  Salad Place
# 19        M5J  ...           Italian Restaurant
# 20        M5K  ...          Japanese Restaurant
# 21        M5L  ...           Seafood Restaurant
# 22        M5N  ...          Dumpling Restaurant
# 23        M5P  ...  Eastern European Restaurant
# 24        M5R  ...               History Museum
# 25        M5S  ...                     Beer Bar
# 26        M5T  ...                 Dessert Shop
# 27        M5V  ...              Harbor / Marina
# 28        M5W  ...                         Park
# 29        M5X  ...                  Salad Place
# 30        M6G  ...                   Restaurant
# 31        M6H  ...                         Park
# 32        M6J  ...                  Pizza Place
# 33        M6K  ...                 Intersection
# 34        M6P  ...           Italian Restaurant
# 35        M6R  ...                    Bookstore
# 36        M6S  ...                Smoothie Shop
# 37        M7A  ...                         Café
# 38        M7Y  ...                       Garden
#
# [39 rows x 13 columns]

# %% [markdown]
# # The section we've all been waiting for, Cluster the areas using k-means
#
# *After multiple trails with 4 and 6 clusters, 5 gave much satisfying results*

# %%
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop(["PostalCode", "Borough", "Neighborhoods"], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 0, 0, 0, 2, 0, 0, 0, 3, 0], dtype=int32)

# %%
toronto_merged = toronto_df_new.copy()

# add clustering labels
toronto_merged["Cluster Labels"] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.drop(["Borough", "Neighborhoods"], 1).set_index("PostalCode"), on="PostalCode")

print(toronto_merged.shape)
toronto_merged.head() # check the last columns!
# Out:
# (39, 16)
#   PostalCode          Borough  ... 9th Most Common Venue  10th Most Common Venue
# 0        M4E     East Toronto  ...               Dog Run        Doner Restaurant
# 1        M4K     East Toronto  ...       Bubble Tea Shop     Japanese Restaurant
# 2        M4L     East Toronto  ...            Steakhouse              Restaurant
# 3        M4M     East Toronto  ...             Pet Store                    Park
# 4        M4N  Central Toronto  ...   Dumpling Restaurant              Donut Shop
#
# [5 rows x 16 columns]

# %%
print(toronto_merged.shape)
toronto_merged.sort_values(["Cluster Labels"], inplace=True)
toronto_merged
# Out:
# (39, 16)
#    PostalCode  ...       10th Most Common Venue
# 19        M5J  ...           Italian Restaurant
# 21        M5L  ...           Seafood Restaurant
# 23        M5P  ...  Eastern European Restaurant
# 24        M5R  ...               History Museum
# 25        M5S  ...                     Beer Bar
# 26        M5T  ...                 Dessert Shop
# 27        M5V  ...              Harbor / Marina
# 28        M5W  ...                         Park
# 29        M5X  ...                  Salad Place
# 30        M6G  ...                   Restaurant
# 31        M6H  ...                         Park
# 32        M6J  ...                  Pizza Place
# 33        M6K  ...                 Intersection
# 34        M6P  ...           Italian Restaurant
# 35        M6R  ...                    Bookstore
# 36        M6S  ...                Smoothie Shop
# 20        M5K  ...          Japanese Restaurant
# 37        M7A  ...                         Café
# 38        M7Y  ...                       Garden
# 17        M5G  ...   Modern European Restaurant
# 1         M4K  ...          Japanese Restaurant
# 2         M4L  ...                   Restaurant
# 3         M4M  ...                         Park
# 5         M4P  ...               Discount Store
# 6         M4R  ...           Miscellaneous Shop
# 7         M4S  ...                     Pharmacy
# 18        M5H  ...                  Salad Place
# 9         M4V  ...                  Supermarket
# 11        M4X  ...                        Diner
# 12        M4Y  ...                        Hotel
# 13        M5A  ...               Farmers Market
# 14        M5B  ...         Fast Food Restaurant
# 15        M5C  ...               Lingerie Store
# 16        M5E  ...                    Irish Pub
# 22        M5N  ...          Dumpling Restaurant
# 4         M4N  ...                   Donut Shop
# 8         M4T  ...                   Donut Shop
# 10        M4W  ...                   Donut Shop
# 0         M4E  ...             Doner Restaurant
#
# [39 rows x 16 columns]

# %% [markdown]
# # Visualise the clusters using folium

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, post, bor, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['PostalCode'], toronto_merged['Borough'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup('{} ({}): {} - Cluster {}'.format(bor, post, poi, cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Examining the clusters

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...       10th Most Common Venue
# 19  Downtown Toronto  ...           Italian Restaurant
# 21  Downtown Toronto  ...           Seafood Restaurant
# 23   Central Toronto  ...  Eastern European Restaurant
# 24   Central Toronto  ...               History Museum
# 25  Downtown Toronto  ...                     Beer Bar
# 26  Downtown Toronto  ...                 Dessert Shop
# 27  Downtown Toronto  ...              Harbor / Marina
# 28  Downtown Toronto  ...                         Park
# 29  Downtown Toronto  ...                  Salad Place
# 30  Downtown Toronto  ...                   Restaurant
# 31      West Toronto  ...                         Park
# 32      West Toronto  ...                  Pizza Place
# 33      West Toronto  ...                 Intersection
# 34      West Toronto  ...           Italian Restaurant
# 35      West Toronto  ...                    Bookstore
# 36      West Toronto  ...                Smoothie Shop
# 20  Downtown Toronto  ...          Japanese Restaurant
# 37  Downtown Toronto  ...                         Café
# 38      East Toronto  ...                       Garden
# 17  Downtown Toronto  ...   Modern European Restaurant
# 1       East Toronto  ...          Japanese Restaurant
# 2       East Toronto  ...                   Restaurant
# 3       East Toronto  ...                         Park
# 5    Central Toronto  ...               Discount Store
# 6    Central Toronto  ...           Miscellaneous Shop
# 7    Central Toronto  ...                     Pharmacy
# 18  Downtown Toronto  ...                  Salad Place
# 9    Central Toronto  ...                  Supermarket
# 11  Downtown Toronto  ...                        Diner
# 12  Downtown Toronto  ...                        Hotel
# 13  Downtown Toronto  ...               Farmers Market
# 14  Downtown Toronto  ...         Fast Food Restaurant
# 15  Downtown Toronto  ...               Lingerie Store
# 16  Downtown Toronto  ...                    Irish Pub
#
# [34 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  ...  10th Most Common Venue
# 22  Central Toronto  ...     Dumpling Restaurant
#
# [1 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#            Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 4  Central Toronto               2  ...   Dumpling Restaurant             Donut Shop
#
# [1 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  ...  10th Most Common Venue
# 8    Central Toronto  ...              Donut Shop
# 10  Downtown Toronto  ...              Donut Shop
#
# [2 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 0  East Toronto               4  ...               Dog Run       Doner Restaurant
#
# [1 rows x 12 columns]

# %% [markdown]
# Observations:
#
# Cluster 1 <br>
# Most of the neighborhoods fall under cluster one, wich are businesses like hotels, pubs, restraunts etc.
#
# Cluster 2 is a Garden
#
# Cluster 3 are park and playground
#
# Cluster 4 are a part and swim school.
#
# Cluster 5 is a trail.
